# %%
import numpy as np

# %%
a = np.array([0, 1, 2])
b = np.array([5, 5, 5])
a + b
# Out:
# array([5, 6, 7])

# %%
## adding scalar to an array

a + 5
# Out:
# array([5, 6, 7])

# %%
## two dimentional array

M = np.ones((3, 3))
M
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
M + a
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.],
#        [1., 2., 3.]])

# %%
a = np.arange(3)
b = np.arange(3)[:, np.newaxis]
print(a)
print(b)
# Out:
# [0 1 2]
# [[0]
#  [1]
#  [2]]

# %%
a + b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %% [markdown]
# ## Rules

# %%
## Broadcasting example 1
## Let’s look at adding a two-dimensional array to a one-dimensional array:

M = np.ones((2, 3))
a = np.arange(3)

print("M =", M)
print("a =", a)
# Out:
# M = [[1. 1. 1.]
#  [1. 1. 1.]]
# a = [0 1 2]

# %%
print(M.shape)
print(a.shape)
# Out:
# (2, 3)
# (3,)

# %%
M + a
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.]])

# %%
## Broadcasting example 2
## Let’s take a look at an example where both arrays need to be broadcast:

a = np.arange(3).reshape((3, 1))
b = np.arange(3)

# %%
a.shape
# Out:
# (3, 1)

# %%
b.shape
# Out:
# (3,)

# %%
a + b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %%
## Broadcasting example 3
## Now let’s take a look at an example in which the two arrays are not compatible:

M = np.ones((3, 2))
a = np.arange(3)

# %%
M.shape
# Out:
# (3, 2)

# %%
a.shape
# Out:
# (3,)

# %%
M + a ## not compatible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22476/3374645918.py in <module>
# ----> 1 M + a
#
# ValueError: operands could not be broadcast together with shapes (3,2) (3,)

# %%
## you can pad the right side instead by reshaping

a[:, np.newaxis].shape
# Out:
# (3, 1)

# %%
M + a[:, np.newaxis]
# Out:
# array([[1., 1.],
#        [2., 2.],
#        [3., 3.]])

# %%
## ufunc

np.logaddexp(M, a[:, np.newaxis])
# Out:
# array([[1.31326169, 1.31326169],
#        [1.69314718, 1.69314718],
#        [2.31326169, 2.31326169]])

# %% [markdown]
# # Broadcasting in Practice

# %% [markdown]
# ## Centering an array

# %%
X = np.random.random((10, 3))

# %%
## We can compute the mean of each feature using the mean aggregate across the first dimension:

Xmean = X.mean(0)
Xmean
# Out:
# array([0.43421602, 0.32950582, 0.64909156])

# %%
## And now we can center the X array by subtracting the mean (this is a broadcasting operation):

X_centered = X - Xmean

# %%
## To double-check that we’ve done this correctly, we can check that the centered array
## has near zero mean:

X_centered.mean(0)
# Out:
# array([-6.66133815e-17, -3.33066907e-17,  5.55111512e-17])

# %% [markdown]
# ## Plotting a two-dimensional function

# %%
# x and y have 50 steps from 0 to 5
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 50)[:, np.newaxis]
z = np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
## import matplotlib

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.imshow(z, origin='lower', extent=[0, 5, 0, 5],
        cmap='viridis')
plt.colorbar();
